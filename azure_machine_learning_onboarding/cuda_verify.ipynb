# %%
print('hello world')
# Out:
# hello world

# %%
import torch

print(torch.version.cuda)
print(torch.cuda.is_available())
# Out:
# 12.1
# False

# %%
device_count = torch.cuda.device_count()
print(f"CUDA is available. Found {device_count} GPU(s):")

for i in range(device_count):
    device_name = torch.cuda.get_device_name(i)
    device_capability = torch.cuda.get_device_capability(i)
    print(f"  Device {i}: {device_name} (Compute Capability: {device_capability[0]}.{device_capability[1]})")
# Out:
# CUDA is available. Found 1 GPU(s):
#   Device 0: Tesla V100-PCIE-16GB (Compute Capability: 7.0)

# %% [markdown]
# (hstu) azureuser@v100x1:~/cloudfiles/code/Users/menghaoyang/src/lrm/generative-recommenders$ mkdir -p tmp/ && python3 preprocess_public_data.py
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/v100x1/code/Users/menghaoyang/src/lrm/generative-recommenders/generative_recommenders/research/data/preprocessor.py:150: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   users = pd.read_csv(
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/v100x1/code/Users/menghaoyang/src/lrm/generative-recommenders/generative_recommenders/research/data/preprocessor.py:155: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   ratings = pd.read_csv(
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/v100x1/code/Users/menghaoyang/src/lrm/generative-recommenders/generative_recommenders/research/data/preprocessor.py:160: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   movies = pd.read_csv(
# ml-1m #item before normalize: 3706
# ml-1m max item id before normalize: 3952
# ml-1m
#    item_ids_mean  item_ids_min  item_ids_max
# 0     165.597517            20          2314
# ml-1m: train num user: 5436
# ml-1m: test num user: 604
# ml-20m #item before normalize: 26744
# ml-20m max item id before normalize: 131262
# ml-20m
#    item_ids_mean  item_ids_min  item_ids_max
# 0      144.41353            20          9254
# ml-20m: train num user: 124643
# ml-20m: test num user: 13850
# amzn_books #data points before filter: 22507155
# amzn_books #user before filter: 8026324
# amzn_books #item before filter: 2330066
# amzn_books #data points after filter: 10444211
# amzn_books #user after filter: 811227
# amzn_books #item ater filter: 695762
# amzn_books
#    item_ids_mean  item_ids_min  item_ids_max
# 0      14.467016             5         27508
# INFO:root:695762 unique items.

# %%
# %load_ext tensorboard
# %tensorboard --logdir ~/exps/ml-1m-l200/ --reload_interval=10
# Out:
# Launching TensorBoard...

# %%
# %pip uninstall torch-tb-profiler
# Out:
# WARNING: Skipping torch-tb-profiler as it is not installed.
# Note: you may need to restart the kernel to use updated packages.
