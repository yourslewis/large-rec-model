# %%
# Handle to the workspace
from azure.ai.ml import MLClient

# Authentication package
from azure.identity import DefaultAzureCredential

credential = DefaultAzureCredential()

# Get a handle to the workspace. You can find the info on the workspace tab on ml.azure.com
ml_client = MLClient(
    credential=credential,
    subscription_id="972cf06a-de12-45b1-87f1-3724a2166e79",  # this will look like xxxxxxxx-xxxx-xxxx-xxxx-xxxxxxxxxxxx
    resource_group_name="Ads-Singularity-RG-01",
    workspace_name="ads-singularity-ws01-eastus",
)

# %%
# Verify that the handle works correctly.
# If you ge an error here, modify your SUBSCRIPTION, RESOURCE_GROUP, and WS_NAME in the previous cell.
ws = ml_client.workspaces.get("ads-singularity-ws01-eastus")
print(ws.location, ":", ws.resource_group)
# Out:
# Timeout was exceeded in force_flush().
# eastus : Ads-Singularity-RG-01

# %%
from azure.ai.ml.entities import Environment
env_docker_conda = Environment(
    image="mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04",
    conda_file="./environment_dev.yml",
    name="hstu",
    version="3.3_dev2",
    description="hstu env.",
)
ml_client.environments.create_or_update(env_docker_conda)
# Out:
# Environment({'arm_type': 'environment_version', 'latest_version': None, 'image': 'mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04', 'intellectual_property': None, 'is_anonymous': False, 'auto_increment_version': False, 'auto_delete_setting': None, 'name': 'hstu', 'description': 'hstu env.', 'tags': {}, 'properties': {'azureml.labels': 'latest'}, 'print_as_yaml': False, 'id': '/subscriptions/972cf06a-de12-45b1-87f1-3724a2166e79/resourceGroups/Ads-Singularity-RG-01/providers/Microsoft.MachineLearningServices/workspaces/ads-singularity-ws01-eastus/environments/hstu/versions/3.3_dev2', 'Resource__source_path': '', 'base_path': '/home/azureuser/localfiles/large-rec-model/src/hstu_retrieval', 'creation_context': <azure.ai.ml.entities._system_data.SystemData object at 0x73c1e68039a0>, 'serialize': <msrest.serialization.Serializer object at 0x73c1e6803d00>, 'version': '3.3_dev2', 'conda_file': {'channels': ['conda-forge', 'defaults', 'https://repo.anaconda.com/pkgs/main', 'https://repo.anaconda.com/pkgs/r'], 'dependencies': ['_libgcc_mutex=0.1=main', '_openmp_mutex=4.5=1_gnu', 'asttokens=3.0.0=py310h06a4308_0', 'bzip2=1.0.8=h5eee18b_6', 'ca-certificates=2025.2.25=h06a4308_0', 'comm=0.2.2=pyhd8ed1ab_1', 'debugpy=1.8.13=py310hf71b8c6_0', 'decorator=5.2.1=pyhd8ed1ab_0', 'exceptiongroup=1.3.0=pyhd8ed1ab_0', 'executing=2.1.0=pyhd8ed1ab_1', 'importlib-metadata=8.6.1=pyha770c72_0', 'ipykernel=6.29.5=py310h06a4308_1', 'ipython=8.34.0=pyh907856f_0', 'jedi=0.19.2=py310h06a4308_0', 'jupyter_client=8.6.3=py310h06a4308_0', 'jupyter_core=5.7.2=py310h06a4308_0', 'keyutils=1.6.1=h166bdaf_0', 'krb5=1.21.3=h143b758_0', 'ld_impl_linux-64=2.43=h712a8e2_4', 'libedit=3.1.20250104=pl5321h7949ede_0', 'libffi=3.4.6=h2dba641_1', 'libgcc=14.2.0=h767d61c_2', 'libgcc-ng=14.2.0=h69a702a_2', 'libgomp=14.2.0=h767d61c_2', 'liblzma=5.6.4=hb9d3cd8_0', 'liblzma-devel=5.6.4=hb9d3cd8_0', 'libnsl=2.0.1=hd590300_0', 'libsodium=1.0.20=h4ab18f5_0', 'libsqlite=3.49.1=hee588c1_2', 'libstdcxx=14.2.0=h8f9b012_2', 'libstdcxx-ng=14.2.0=h4852527_2', 'libuuid=2.38.1=h0b41bf4_0', 'libxcrypt=4.4.36=hd590300_1', 'libzlib=1.3.1=hb9d3cd8_2', 'matplotlib-inline=0.1.7=pyhd8ed1ab_1', 'ncurses=6.5=h2d0b736_3', 'nest-asyncio=1.6.0=py310h06a4308_0', 'openssl=3.4.1=h7b32b05_0', 'packaging=25.0=pyh29332c3_1', 'parso=0.8.4=py310h06a4308_0', 'pexpect=4.9.0=pyhd8ed1ab_1', 'pickleshare=0.7.5=pyhd3eb1b0_1003', 'pip=25.0.1=pyh8b19718_0', 'platformdirs=4.3.6=pyhd8ed1ab_1', 'prompt-toolkit=3.0.50=pyha770c72_0', 'ptyprocess=0.7.0=pyhd3eb1b0_2', 'pure_eval=0.2.3=pyhd8ed1ab_1', 'pygments=2.19.1=py310h06a4308_0', 'python=3.10.16=habfa6aa_2_cpython', 'python-dateutil=2.9.0.post0=py310h06a4308_1', 'python_abi=3.10=7_cp310', 'pyzmq=26.2.1=py310h71f11fc_0', 'readline=8.2=h5eee18b_0', 'setuptools=75.8.2=pyhff2d567_0', 'six=1.17.0=py310h06a4308_0', 'sqlite=3.49.1=h9eae976_2', 'stack_data=0.6.3=pyhd8ed1ab_1', 'tk=8.6.13=noxft_hd72426e_102', 'tornado=6.4.2=py310h5eee18b_0', 'tqdm=4.67.1=py310h2f386ee_0', 'traitlets=5.14.3=py310h06a4308_0', 'wcwidth=0.2.13=pyhd8ed1ab_1', 'wheel=0.45.1=py310h06a4308_0', 'xz=5.6.4=hbcc6ac9_0', 'xz-gpl-tools=5.6.4=hbcc6ac9_0', 'xz-tools=5.6.4=hb9d3cd8_0', 'zeromq=4.3.5=h3b0a872_7', 'zipp=3.23.0=pyhd8ed1ab_0', 'zlib=1.3.1=hb9d3cd8_2', {'pip': ['absl-py==2.1.0', 'alembic==1.16.1', 'annotated-types==0.7.0', 'anyio==4.9.0', 'asgiref==3.8.1', 'attrs==25.3.0', 'azure-ai-ml==1.27.1', 'azure-common==1.1.28', 'azure-core==1.34.0', 'azure-core-tracing-opentelemetry==1.0.0b12', 'azure-identity==1.23.0', 'azure-mgmt-core==1.5.0', 'azure-monitor-opentelemetry==1.6.9', 'azure-monitor-opentelemetry-exporter==1.0.0b36', 'azure-storage-blob==12.19.0', 'azure-storage-file-datalake==12.9.0', 'azure-storage-file-share==12.21.0', 'azureml-dataprep==5.1.6', 'azureml-dataprep-native==41.0.0', 'azureml-dataprep-rslex==2.22.5', 'azureml-fsspec==1.3.1', 'azureml-mlflow==1.60.0', 'blinker==1.9.0', 'cachetools==5.5.2', 'certifi==2025.4.26', 'cffi==1.17.1', 'charset-normalizer==3.4.2', 'click==8.2.1', 'cloudpick ...
