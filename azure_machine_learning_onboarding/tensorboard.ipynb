# %% [markdown]
# ### Access data/logs from a datastore URI, like a filesystem

# %%
# Azure Machine Learning workspace details:
subscription = '72a1fe05-772c-4836-869f-761a5805fcd4'
resource_group = 'Ads-Singularity-RG-01'
workspace = 'ads-singularity-ws01-eastus'
datastore_name = 'workspaceblobstore'
path_on_datastore = 'azureml/busy_eye_h3flh114w7/logs'

# long-form Datastore uri format:
uri = f'azureml://subscriptions/{subscription}/resourcegroups/{resource_group}/workspaces/{workspace}/datastores/{datastore_name}/paths/{path_on_datastore}'

# %%
from azureml.fsspec import AzureMachineLearningFileSystem

# instantiate file system using following URI
fs = AzureMachineLearningFileSystem(uri)

fs.ls() # list folders/files in datastore 'datastorename'
# Out:
# Timeout was exceeded in force_flush().
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Overriding of current MeterProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# ['azureml/busy_eye_h3flh114w7/logs/exps/']

# %%
fs.download(rpath=uri, lpath='.', recursive=True)

# %% [markdown]
# ### Start Tensorboard

# %%
from azureml.tensorboard import Tensorboard

# The TensorBoard constructor takes an array of jobs, so be sure and pass it in as a single-element array here
logdir = './exps/ml-1m-l200'
tb = Tensorboard([], local_root=logdir, port=6006)

# If successful, start() returns a string with the URI of the instance.
tb.start()
# Out:
# https://dev-6006.westus.instances.azureml.ms
# 'https://dev-6006.westus.instances.azureml.ms'
