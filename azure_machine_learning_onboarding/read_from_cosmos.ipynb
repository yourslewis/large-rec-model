# %%
print('hello world!')
# Out:
# hello world!

# %%
# Handle to the workspace
from azure.ai.ml import MLClient

# Authentication package
from azure.identity import DefaultAzureCredential

credential = DefaultAzureCredential()

# Get a handle to the workspace. You can find the info on the workspace tab on ml.azure.com
ml_client = MLClient(
    credential=credential,
    subscription_id="f920ee3b-6bdc-48c6-a487-9e0397b69322",  # this will look like xxxxxxxx-xxxx-xxxx-xxxx-xxxxxxxxxxxx
    resource_group_name="msan-aml",
    workspace_name="menghao-dev",
)

# %%
# Verify that the handle works correctly.
# If you ge an error here, modify your SUBSCRIPTION, RESOURCE_GROUP, and WS_NAME in the previous cell.
ws = ml_client.workspaces.get("menghao-dev")
print(ws.location, ":", ws.resource_group)
# Out:
# westus : msan-aml

# %%
# Azure Machine Learning workspace details:
subscription = 'f920ee3b-6bdc-48c6-a487-9e0397b69322'
resource_group = 'msan-aml'
workspace = 'menghao-dev'
datastore_name = 'bingads_algo_prod_networkprotection_c08'
path_on_datastore = '/local/users/menghao/fake.csv'

# long-form Datastore uri format:
uri = f'azureml://subscriptions/{subscription}/resourcegroups/{resource_group}/workspaces/{workspace}/datastores/{datastore_name}/paths/{path_on_datastore}'

import pandas as pd
data = pd.read_csv(uri)
# Out:
# Resolving access token for scope "https://datalake.azure.net//.default" using identity of type "MANAGED".
# Getting data access token with Assigned Identity (client_id=clientid) and endpoint type based on configuration

# %%
data
# Out:
#          Name             Email  Phone Number          Address
# 0   Bob Smith   bob@example.com  123-456-7890  123 Fake Street
# 1  Mike Jones  mike@example.com  098-765-4321  321 Fake Avenue
